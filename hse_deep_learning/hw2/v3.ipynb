# %%
import torch
import torch.nn as nn
import torchvision.models
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import torch.nn.functional as F

import albumentations as A
from albumentations.pytorch import ToTensorV2

from tqdm import tqdm
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np

import os
from time import time
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.20 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %% [markdown]
# ### Get the data

# %%
import gdown
url = 'https://drive.google.com/uc?id=10f1H2T-5W-BiqabHHtlZ4ASs19TZmg8R'
output = 'data.zip'
gdown.download(url, output, quiet=False)
# !unzip data.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=10f1H2T-5W-BiqabHHtlZ4ASs19TZmg8R
# From (redirected): https://drive.google.com/uc?id=10f1H2T-5W-BiqabHHtlZ4ASs19TZmg8R&confirm=t&uuid=558ce7b5-3afa-4b45-840b-9e78a2cef627
# To: /content/data.zip
# 100%|██████████| 979M/979M [00:09<00:00, 108MB/s]
# Streaming output truncated to the last 5000 lines.
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0098_51410.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0115_51891.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0106_52729.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0056_51523.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0113_51525.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0009_51301.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0117_51363.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0104_52614.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0108_51108.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0029_52613.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0119_51551.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0118_51322.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0100_52779.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0001_51416.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0128_51403.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0045_50215.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0092_51521.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0039_50191.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0063_51256.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0021_51300.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0101_51375.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0083_51407.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0020_50204.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0127_51485.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0016_50392.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0052_51357.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0054_51414.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0051_51440.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0017_51412.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0078_51494.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0125_51307.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0131_51370.jpg
#   inflating: data/train/images/064.Ring_billed_Gull/Ring_Billed_Gull_0003_51480.jpg
#    creating: data/train/images/035.Purple_Finch/
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0111_27293.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0096_27688.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0002_27266.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0020_27961.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0031_28175.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0074_28101.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0124_27567.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0065_27473.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0094_27323.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0013_27506.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0014_27322.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0033_27926.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0050_27702.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0108_28143.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0120_27597.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0081_27913.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0071_27443.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0001_27571.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0046_27295.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0088_28076.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0117_27427.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0011_27633.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0091_27425.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0103_27461.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0114_27837.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0118_27604.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0119_27260.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0104_28088.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0079_27258.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0130_27555.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0006_27950.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0076_27441.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0092_27264.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0086_27637.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0067_27431.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0113_27547.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0106_27607.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0082_27639.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0134_27526.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0133_27928.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0102_27308.jpg
#   inflating: data/train/images/035.Purple_Finch/Purple_Finch_0115_28190.jpg
#    creating: data/train/images/118.House_Sparrow/
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0128_110971.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0125_111130.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0008_111204.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0074_111997.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0130_110985.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0007_111029.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0052_112252.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0061_112795.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0004_111989.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0127_111935.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0049_110976.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0046_112845.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0126_110959.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0019_112645.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0055_111393.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0108_112963.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0083_111470.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0098_111073.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0050_111087.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0025_111669.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0063_111460.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0120_113001.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0144_113216.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0033_112590.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0093_110990.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0145_112703.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0079_113288.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0104_113105.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0094_112773.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0092_111413.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0041_112706.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0030_111387.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0036_112847.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0137_111219.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0015_111085.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0119_111471.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0106_111564.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0059_111164.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0028_113217.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0068_113247.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0086_111385.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0143_111400.jpg
#   inflating: data/train/images/118.House_Sparrow/House_Sparrow_0082_112478.jpg
#    creating: data/train/images/061.Heermann_Gull/
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0136_45416.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0043_45939.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0089_45679.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0009_45905.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0087_45658.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0015_41392.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0083_45879.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0020_45409.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0013_45771.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0098_45753.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0071_45735.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0046_45888.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0056_45751.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0077_45711.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0079_45468.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0112_45748.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0131_45548.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0086_45304.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0122_45627.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0034_45693.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0031_45822.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0059_45642.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0111_45652.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0073_45714.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0138_45269.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0090_45834.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0091_45363.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0093_45576.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0130_45700.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0121_45375.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0115_45797.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0102_45904.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0110_45968.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0133_45415.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0001_45472.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0055_45901.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0035_45754.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0109_45619.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0118_45626.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0018_45608.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0053_45854.jpg
#   inflating: data/train/images/061.Heermann_Gull/Heermann_Gull_0074_45351.jpg
#    creating: data/train/images/066.Western_Gull/
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0052_53485.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0042_53843.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0093_54925.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0029_54143.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0043_54706.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0012_53605.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0143_54909.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0036_54329.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0104_53816.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0066_54105.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0099_53670.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0122_40866.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0128_53852.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0049_53748.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0087_54193.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0045_54735.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0090_53603.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0089_55306.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0114_55644.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0094_55156.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0133_55639.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0116_54037.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0035_55703.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0022_54607.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0050_54425.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0030_54083.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0002_54825.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0009_54768.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0078_53595.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0117_44697.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0131_53349.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0041_53554.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0058_53882.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0115_54950.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0025_55421.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0004_55605.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0051_54320.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0069_53553.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0091_55465.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0011_53713.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0073_54118.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0110_53861.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0057_55312.jpg
#   inflating: data/train/images/066.Western_Gull/Western_Gull_0100_54761.jpg
#    creating: data/train/images/057.Rose_breasted_Grosbeak/
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0101_39495.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0077_39613.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0125_39597.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0020_39152.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0108_39000.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0060_39279.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0067_39592.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0089_39211.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0051_39798.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0063_39802.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0122_39284.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0103_39580.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0012_39149.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0062_39234.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0001_39801.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0052_39044.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0128_39204.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0110_39373.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0088_39035.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0092_39367.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0047_39407.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0055_39154.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0135_39227.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0003_39223.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0087_39280.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0126_39361.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0114_39770.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0014_39037.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0011_39207.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0033_39290.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0026_39191.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0104_39189.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0010_39238.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0042_39158.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0017_39161.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0086_39658.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0068_39094.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0032_39772.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0084_39053.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0029_39434.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0018_39731.jpg
#   inflating: data/train/images/057.Rose_breasted_Grosbeak/Rose_Breasted_Grosbeak_0059_39045.jpg
#    creating: data/train/images/179.Tennessee_Warbler/
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0087_174968.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0015_174847.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0043_175003.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0050_174851.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0040_174933.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0071_175084.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0080_167714.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0046_174798.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0051_175015.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0088_175163.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0045_174913.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0021_174761.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0014_175126.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0091_175050.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0007_174796.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0025_174973.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0063_168561.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0013_163552.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0062_174949.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0092_174810.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0024_174980.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0009_174937.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0076_174807.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0003_175154.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0039_174883.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0060_174840.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0065_174757.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0054_174914.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0027_174805.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0070_174962.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0033_174772.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0067_174999.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0100_175168.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0026_175118.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0052_175089.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0004_174997.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0041_174900.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0030_172338.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0049_175006.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0089_174764.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0002_174884.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0044_174824.jpg
#   inflating: data/train/images/179.Tennessee_Warbler/Tennessee_Warbler_0085_156530.jpg
#    creating: data/train/images/063.Ivory_Gull/
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0043_49755.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0040_49180.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0107_49186.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0036_49754.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0085_49456.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0073_49287.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0037_49068.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0117_49227.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0096_49487.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0010_49169.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0041_49172.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0092_49996.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0089_49699.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0093_49052.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0024_49195.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0077_49051.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0071_49402.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0004_49019.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0052_50013.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0059_49662.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0026_49466.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0039_49412.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0067_49659.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0088_49177.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0015_49199.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0094_49347.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0082_49306.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0002_49788.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0055_49353.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0098_49810.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0050_49245.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0099_49218.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0018_49988.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0114_49535.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0086_49532.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0104_49666.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0065_49566.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0118_49191.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0080_49748.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0005_49021.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0101_49790.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0061_49416.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0032_49322.jpg
#   inflating: data/train/images/063.Ivory_Gull/Ivory_Gull_0023_49385.jpg
#    creating: data/train/images/186.Cedar_Waxwing/
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0033_178737.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0072_178058.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0060_178190.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0096_178164.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0101_179707.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0100_178643.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0107_179098.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0062_178788.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0065_179017.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0094_178049.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0003_178570.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0124_178857.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0092_179123.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0074_178888.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0037_179710.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0076_178732.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0098_178971.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0034_179715.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0070_179007.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0077_178191.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0026_178878.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0031_178929.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0006_179394.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0075_179114.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0113_178627.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0010_178891.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0008_178345.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0125_178921.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0095_178163.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0004_179215.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0002_179071.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0083_178743.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0042_179391.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0029_179569.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0011_179149.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0069_179310.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0054_178141.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0024_178230.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0049_178723.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0059_178500.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0066_178719.jpg
#   inflating: data/train/images/186.Cedar_Waxwing/Cedar_Waxwing_0016_178629.jpg
#    creating: data/train/images/075.Green_Jay/
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0124_65848.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0041_65548.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0071_65799.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0085_66077.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0036_65660.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0075_65701.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0118_66251.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0104_65908.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0038_65702.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0098_65857.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0128_65629.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0043_65805.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0003_65767.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0130_65885.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0042_65740.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0114_65841.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0094_65775.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0027_65783.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0006_65788.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0051_65662.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0016_65864.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0074_65889.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0077_65736.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0115_65745.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0029_65637.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0126_65716.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0028_65719.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0092_65884.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0020_66168.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0102_65813.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0100_65786.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0040_65863.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0132_65886.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0106_65811.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0044_66228.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0039_66118.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0055_65807.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0064_65552.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0011_65947.jpg
#   inflating: data/train/images/075.Green_Jay/Green_Jay_0023_65898.jpg
#    creating: data/train/images/024.Red_faced_Cormorant/
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0001_796327.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0010_23421.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0009_796314.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0002_796275.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0003_796270.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0072_796269.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0036_796329.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0024_796285.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0028_796322.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0069_796274.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0053_796331.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0061_796300.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0017_796323.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0015_796307.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0066_796333.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0039_796308.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0049_796279.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0052_796316.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0060_23416.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0068_796321.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0057_796286.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0023_796328.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0042_796277.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0021_796265.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0045_796324.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0026_796289.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0032_796334.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0056_796297.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0063_796284.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0050_796276.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0058_796315.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0035_796294.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0033_796337.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0046_23446.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0038_796313.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0040_796272.jpg
#   inflating: data/train/images/024.Red_faced_Cormorant/Red_Faced_Cormorant_0064_23464.jpg
#    creating: data/train/images/106.Horned_Puffin/
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0019_101063.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0010_100771.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0015_100889.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0073_100830.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0033_100731.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0065_100625.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0079_100847.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0042_100760.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0036_100974.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0078_100777.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0016_100993.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0061_100845.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0006_100989.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0056_101030.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0082_100876.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0035_100690.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0003_101045.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0074_100886.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0052_100977.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0039_100890.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0072_100938.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0007_100699.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0071_100651.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0045_100803.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0028_100765.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0026_100937.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0038_100635.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0031_100804.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0060_100726.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0081_101054.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0068_100872.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0030_100725.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0077_100671.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0054_100915.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0004_100733.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0050_100645.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0012_100763.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0066_100877.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0001_100973.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0011_100621.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0069_101018.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0021_100780.jpg
#   inflating: data/train/images/106.Horned_Puffin/Horned_Puffin_0055_100882.jpg
#    creating: data/train/images/098.Scott_Oriole/
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0081_92374.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0078_795833.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0042_795844.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0031_90270.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0072_795822.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0057_795856.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0075_795817.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0036_795850.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0001_795826.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0085_92206.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0022_92356.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0029_795846.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0054_92310.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0067_795858.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0025_92207.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0011_795836.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0002_795829.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0083_795821.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0030_795830.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0043_795828.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0070_795808.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0016_92398.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0065_795819.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0044_92262.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0034_795813.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0055_795825.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0051_795807.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0053_795805.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0015_795862.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0079_92248.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0063_795812.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0045_92237.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0052_92440.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0012_795837.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0056_795816.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0058_795849.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0032_795810.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0038_795818.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0003_92247.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0073_92369.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0040_795839.jpg
#   inflating: data/train/images/098.Scott_Oriole/Scott_Oriole_0014_795827.jpg
#    creating: data/train/images/182.Yellow_Warbler/
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0096_176586.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0042_176460.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0090_176366.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0097_176538.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0094_176365.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0071_176655.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0112_176301.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0043_176247.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0095_176202.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0004_176947.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0069_176346.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0011_176676.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0044_176367.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0083_176292.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0057_176675.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0030_176236.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0118_176409.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0088_176336.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0063_176800.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0039_176444.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0017_176888.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0016_176452.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0123_176471.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0102_176821.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0021_176421.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0007_176616.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0106_176383.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0087_176591.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0026_176337.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0122_176182.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0056_176320.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0047_176456.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0025_176189.jpg
#   inflating: data/train/images/182.Yellow_Warbler/Yellow_Warbler_0003_176429.jpg
# ...
#   inflating: data/train/images/079.Belted_Kingfisher/Belted_Kingfisher_0108_70554.jpg
#   inflating: data/train/images/079.Belted_Kingfisher/Belted_Kingfisher_0008_70668.jpg
#   inflating: data/train/images/079.Belted_Kingfisher/Belted_Kingfisher_0041_70595.jpg
#   inflating: data/train/images/079.Belted_Kingfisher/Belted_Kingfisher_0017_70342.jpg
#   inflating: data/train/images/079.Belted_Kingfisher/Belted_Kingfisher_0077_70620.jpg
#   inflating: data/train/images/079.Belted_Kingfisher/Belted_Kingfisher_0087_70724.jpg
#    creating: data/train/images/041.Scissor_tailed_Flycatcher/
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0076_41597.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0055_42051.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0096_41733.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0008_41670.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0059_41998.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0019_41936.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0126_41905.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0069_41827.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0089_41810.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0077_41688.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0020_41680.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0115_42137.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0004_41643.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0002_41762.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0023_42117.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0094_42018.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0003_41849.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0005_41727.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0122_41679.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0062_41952.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0026_41774.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0092_41767.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0007_41917.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0085_41830.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0100_41796.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0068_41835.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0111_42118.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0072_42085.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0110_42136.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0033_41782.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0012_41853.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0106_41684.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0103_41938.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0044_42002.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0088_41700.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0109_41720.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0006_41601.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0035_42025.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0082_41852.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0098_41731.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0117_42026.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0031_41836.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0123_41638.jpg
#   inflating: data/train/images/041.Scissor_tailed_Flycatcher/Scissor_Tailed_Flycatcher_0028_42010.jpg
#    creating: data/train/images/162.Canada_Warbler/
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0117_162394.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0005_162389.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0113_162403.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0103_162339.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0021_162325.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0085_162385.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0006_103959.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0076_162393.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0051_162447.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0040_162352.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0039_162330.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0016_162411.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0048_162326.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0095_162401.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0019_162409.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0114_162396.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0008_162416.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0077_162437.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0119_162307.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0099_162425.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0090_162432.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0120_162415.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0107_162440.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0027_162223.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0121_162310.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0009_162343.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0035_162377.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0094_26880.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0032_162229.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0056_162407.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0105_162372.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0063_162324.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0122_162219.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0087_162342.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0042_162448.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0004_162224.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0112_162398.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0002_162426.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0007_162364.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0115_162309.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0075_162428.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0093_162356.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0024_162218.jpg
#   inflating: data/train/images/162.Canada_Warbler/Canada_Warbler_0109_93363.jpg
#    creating: data/train/images/023.Brandt_Cormorant/
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0014_23050.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0026_22913.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0025_22820.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0061_22902.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0002_23072.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0064_22849.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0017_23141.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0053_22957.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0030_22926.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0029_23043.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0068_23019.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0062_23038.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0088_22948.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0049_22924.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0073_23259.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0003_22922.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0052_23356.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0045_22916.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0039_22945.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0063_22865.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0079_22874.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0092_23061.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0084_23265.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0006_22925.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0021_23097.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0009_22890.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0036_22937.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0091_22825.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0007_22934.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0071_23007.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0038_23110.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0070_23137.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0018_23090.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0078_23203.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0082_22978.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0032_22886.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0035_23000.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0087_23126.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0016_23077.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0015_23198.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0067_23352.jpg
#   inflating: data/train/images/023.Brandt_Cormorant/Brandt_Cormorant_0022_23157.jpg
#    creating: data/train/images/096.Hooded_Oriole/
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0038_90575.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0104_90264.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0044_90082.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0048_89957.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0087_90037.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0069_90981.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0127_90200.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0043_90499.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0024_90157.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0002_91034.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0014_90594.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0105_90875.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0068_90397.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0095_90337.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0045_90415.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0056_89966.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0047_90637.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0035_90331.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0067_90416.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0037_91156.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0062_90089.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0107_89985.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0106_90899.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0029_90485.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0034_90686.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0074_91081.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0060_90879.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0076_90895.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0082_90045.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0130_90422.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0125_90382.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0075_90788.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0079_89978.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0013_90445.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0117_90464.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0007_91133.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0084_90607.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0006_90685.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0111_89988.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0063_90976.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0072_90298.jpg
#   inflating: data/train/images/096.Hooded_Oriole/Hooded_Oriole_0004_91057.jpg

# %% [markdown]
# ### Utilities (0.5 point)
#
# Complete dataset to load prepared images and masks. Don't forget to use augmentations.
#
# Some of the images are 1 channels, so use `gray2rgb`.

# %% [markdown]
# #### config

# %%
# config/config.py
from dataclasses import dataclass
from typing import Tuple, Optional
import torch


@dataclass
class TrainingConfig:
    """Configuration for training parameters"""
    # Training
    epochs: int = 100
    early_stopping_patience: int = 3
    batch_size: int = 8
    learning_rate: float = 1e-3
    dropout_rate: float = 0.1
    device: str = "cuda" if torch.cuda.is_available() else "cpu"

    # Optimizer
    weight_decay: float = 1e-5
    scheduler_patience: int = 2
    scheduler_factor: float = 0.1

    # Logging
    project_name: str = "bird-segmentation"
    run_name: Optional[str] = None
    use_wandb: bool = True

    # Model
    input_size: Tuple[int, int] = (256, 256)
    num_classes: int = 1
    iou_threshold: float = 0.3
    normalize_mean: Tuple[float, float, float] = (0.485, 0.456, 0.406)
    normalize_std: Tuple[float, float, float] = (0.229, 0.224, 0.225)

# %% [markdown]
# ### Dataset

# %%
# dataset.py
import cv2
import os
from torch.utils.data import Dataset
import albumentations as A
from albumentations.pytorch import ToTensorV2
from typing import Tuple, Optional
import torch


class BirdsDataset(Dataset):
    """Dataset class for bird segmentation"""

    def __init__(
        self,
        folder: str,
        config: TrainingConfig,
        transform: Optional[A.Compose] = None,
        is_training: bool = True
    ) -> None:
        self.image_paths, self.mask_paths = self._get_paths(folder)
        self.transform = transform or (
            self._get_train_transforms(config) if is_training
            else self._get_default_transforms(config)
        )

    def _get_paths(self, folder: str) -> Tuple[list, list]:
        """Get paths for images and masks"""
        images_folder = os.path.join(folder, "images")
        gt_folder = os.path.join(folder, "gt")

        image_paths = []
        mask_paths = []

        for class_name in os.listdir(images_folder):
            class_folder = os.path.join(images_folder, class_name)
            if os.path.isdir(class_folder):
                for fname in os.listdir(class_folder):
                    image_paths.append(os.path.join(class_folder, fname))
                    mask_paths.append(
                        os.path.join(gt_folder, class_name, fname[:-3] + "png")
                    )

        return image_paths, mask_paths

    @staticmethod
    def _get_train_transforms(config: TrainingConfig) -> A.Compose:
        return A.Compose([
            A.RandomResizedCrop(*config.input_size, scale=(0.8, 1.0)),
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            A.RandomRotate90(p=0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
            A.Normalize(mean=config.normalize_mean, std=config.normalize_std),
            ToTensorV2(),
        ])

    @staticmethod
    def _get_default_transforms(config: TrainingConfig) -> A.Compose:
        """Get default transforms for validation"""
        return A.Compose([
            A.Resize(*config.input_size),
            A.Normalize(
                mean=config.normalize_mean,
                std=config.normalize_std
            ),
            ToTensorV2(),
        ])

    def __getitem__(self, index: int) -> Tuple[torch.Tensor, torch.Tensor]:
        """Get a sample from the dataset"""
        # Load images
        img = cv2.imread(self.image_paths[index])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.mask_paths[index], cv2.IMREAD_GRAYSCALE)

        # Apply transforms
        transformed = self.transform(image=img, mask=mask)

        return (
            transformed["image"],
            transformed["mask"].float().unsqueeze(0) / 255.0,
        )

    def __len__(self) -> int:
        return len(self.image_paths)

# %% [markdown]
# ### Architecture (1 point)
# Your task for today is to build your own Unet to solve the segmentation problem.
#
# As an encoder, you can use pre-trained on IMAGENET models(or parts) from torchvision. The decoder must be trained from scratch.
# It is forbidden to use data not from the `data` folder.
#
# I advise you to experiment with the number of blocks so as not to overfit on the training sample and get good quality on validation.

# %%
# models/blocks.py
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision


class AttentionGate(nn.Module):
    """Attention Gate for focusing on relevant features"""

    def __init__(self, F_g: int, F_l: int, F_int: int):
        super().__init__()
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1),
            nn.BatchNorm2d(F_int)
        )
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1),
            nn.BatchNorm2d(F_int)
        )
        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, g: torch.Tensor, x: torch.Tensor) -> torch.Tensor:
        g1 = self.W_g(g)
        x1 = self.W_x(x)
        psi = self.relu(g1 + x1)
        psi = self.psi(psi)
        return x * psi


class ResidualBlock(nn.Module):
    """Residual block for enhanced feature learning"""

    def __init__(self, in_channels: int, out_channels: int):
        super().__init__()
        self.conv_block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, padding=1),
            nn.BatchNorm2d(out_channels)
        )
        self.shortcut = self._make_shortcut(in_channels, out_channels)
        self.relu = nn.ReLU(inplace=True)

    def _make_shortcut(self, in_channels: int, out_channels: int) -> nn.Sequential:
        if in_channels != out_channels:
            return nn.Sequential(
                nn.Conv2d(in_channels, out_channels, 1),
                nn.BatchNorm2d(out_channels)
            )
        return nn.Identity()

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        residual = self.shortcut(x)
        x = self.conv_block(x)
        x += residual
        return self.relu(x)


class DecoderBlock(nn.Module):
    """Decoder block with attention and residual connections"""

    def __init__(self, in_channels: int, skip_channels: int, out_channels: int):
        super().__init__()
        self.attention = AttentionGate(out_channels, skip_channels, out_channels)
        self.upconv = nn.ConvTranspose2d(in_channels, out_channels, 2, stride=2)
        self.residual1 = ResidualBlock(out_channels + skip_channels, out_channels)
        self.residual2 = ResidualBlock(out_channels, out_channels)

    def forward(self, x: torch.Tensor, skip: torch.Tensor) -> torch.Tensor:
        x = self.upconv(x)
        x = self._handle_size_mismatch(x, skip)
        skip = self.attention(x, skip)
        x = torch.cat([x, skip], dim=1)
        x = self.residual1(x)
        x = self.residual2(x)
        return x

    @staticmethod
    def _handle_size_mismatch(x: torch.Tensor, skip: torch.Tensor) -> torch.Tensor:
        if x.shape != skip.shape:
            diff_h = skip.size(2) - x.size(2)
            diff_w = skip.size(3) - x.size(3)
            x = F.pad(x, [diff_w//2, diff_w-diff_w//2, diff_h//2, diff_h-diff_h//2])
        return x


class UNet(nn.Module):
    """U-Net architecture with ResNet50 encoder and attention"""

    def __init__(self, config):
        super().__init__()
        self.config = config

        # Initialize ResNet encoder
        resnet = torchvision.models.resnet50(weights="DEFAULT")

        # Encoder
        self.encoder1 = nn.Sequential(
            resnet.conv1, resnet.bn1, resnet.relu
        )
        self.pool = resnet.maxpool
        self.encoder2 = resnet.layer1  # 256
        self.encoder3 = resnet.layer2  # 512
        self.encoder4 = resnet.layer3  # 1024
        self.encoder5 = resnet.layer4  # 2048

        # Decoder
        self.decoder4 = DecoderBlock(2048, 1024, 512)
        self.decoder3 = DecoderBlock(512, 512, 256)
        self.decoder2 = DecoderBlock(256, 256, 128)
        self.decoder1 = DecoderBlock(128, 64, 64)

        self.final_conv = nn.Conv2d(64, config.num_classes, 1)

    def forward(self, x):
        # Encoder
        enc1 = self.encoder1(x)
        enc2 = self.encoder2(self.pool(enc1))
        enc3 = self.encoder3(enc2)
        enc4 = self.encoder4(enc3)
        enc5 = self.encoder5(enc4)

        # Decoder
        dec4 = self.decoder4(enc5, enc4)
        dec3 = self.decoder3(dec4, enc3)
        dec2 = self.decoder2(dec3, enc2)
        dec1 = self.decoder1(dec2, enc1)

        # Final output
        out = self.final_conv(dec1)
        return nn.functional.interpolate(
            out,
            size=x.shape[2:],
            mode="bilinear",
            align_corners=False
        )

# %% [markdown]
# ### Train script (0.5 point)
#
# Complete the train and predict scripts.

# %% [markdown]
# #### metrics

# %%
# training/trainer.py
import os
import torch
import wandb
from torch.utils.data import DataLoader
from typing import Dict
from tqdm import tqdm


class DiceLoss(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, inputs, targets, smooth=1):
        inputs = torch.sigmoid(inputs)
        inputs = inputs.view(-1)
        targets = targets.view(-1)

        intersection = (inputs * targets).sum()
        dice = (2.0 * intersection + smooth) / (inputs.sum() + targets.sum() + smooth)
        return 1 - dice


class Trainer:
    """Handles model training and validation"""

    def __init__(self, model: torch.nn.Module, config):
        self.model = model
        self.config = config
        self.device = config.device

        # Initialize metrics
        self.metrics = MetricsCalculator()

        # Loss and optimization
        self.criterion = lambda inputs, targets: (
            torch.nn.functional.binary_cross_entropy_with_logits(inputs, targets) +
            DiceLoss()(inputs, targets)
        )
        self.optimizer = torch.optim.AdamW(
            model.parameters(),
            lr=config.learning_rate,
            weight_decay=config.weight_decay
        )
        self.scheduler = torch.optim.lr_scheduler.StepLR(
            self.optimizer, step_size=10, gamma=0.5
        )

        self.early_stopping_patience = config.early_stopping_patience
        self.no_improve_epochs = 0
        self.best_val_loss = float('inf')

        # Setup logging
        if config.use_wandb:
            self._setup_wandb()

    def _setup_wandb(self):
        """Initialize WandB logging"""
        self.run = wandb.init(
            project=self.config.project_name,
            name=self.config.run_name,
            config=self.config
        )
        wandb.watch(self.model, self.criterion, log="all", log_freq=10)

    def train(self, train_loader: DataLoader, val_loader: DataLoader) -> torch.nn.Module:
        """Training loop with validation"""
        for epoch in range(self.config.epochs):
            # Training
            train_metrics = self._train_epoch(train_loader)

            # Validation
            val_metrics = self._validate_epoch(val_loader)

            # Update learning rate
            self.scheduler.step()

            # Logging
            self._log_metrics(epoch, train_metrics, val_metrics)

            # Save best model
            if val_metrics["loss"] > self.best_val_loss:
                best_iou = val_metrics["loss"]
                self._save_checkpoint("best_model.pth")

            # Early stopping
            if val_metrics["loss"] < self.best_val_loss:
                self.best_val_loss = val_metrics["loss"]
                self.no_improve_epochs = 0
                self._save_checkpoint("best_model.pth")
            else:
                self.no_improve_epochs += 1
                if self.no_improve_epochs >= self.early_stopping_patience:
                    print("Early stopping triggered.")
                    break

        if self.config.use_wandb:
            self.run.finish()

        return self.model

    def _train_epoch(self, dataloader: DataLoader) -> Dict[str, float]:
        """Single training epoch"""
        self.model.train()
        self.metrics.reset()

        for inputs, targets in tqdm(dataloader, desc="Training"):
            # Move data to device
            inputs = inputs.to(self.device)
            targets = targets.to(self.device)

            # Forward pass
            outputs = self.model(inputs)
            loss = self.criterion(outputs, targets)

            # Backward pass
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

            # Calculate metrics
            with torch.inference_mode():
                iou = self.metrics.calculate_iou(outputs, targets, self.config.iou_threshold)
                self.metrics.update(loss.item(), iou)

        return self.metrics.compute()

    def _validate_epoch(self, dataloader: DataLoader) -> Dict[str, float]:
        """Single validation epoch"""
        self.model.eval()
        self.metrics.reset()

        with torch.inference_mode():
            for inputs, targets in tqdm(dataloader, desc="Validation"):
                # Move data to device
                inputs = inputs.to(self.device)
                targets = targets.to(self.device)

                # Forward pass
                outputs = self.model(inputs)
                loss = self.criterion(outputs, targets)

                # Calculate metrics
                iou = self.metrics.calculate_iou(outputs, targets, self.config.iou_threshold)
                self.metrics.update(loss.item(), iou)

        return self.metrics.compute()

    def _log_metrics(
        self,
        epoch: int,
        train_metrics: Dict[str, float],
        val_metrics: Dict[str, float]
    ) -> None:
        """Log metrics to console and WandB if enabled"""
        # Console logging
        print(f"\nEpoch {epoch + 1}/{self.config.epochs}")
        print(f"Train Loss: {train_metrics['loss']:.4f} - Train IoU: {train_metrics['iou']:.4f}")
        print(f"Val Loss: {val_metrics['loss']:.4f} - Val IoU: {val_metrics['iou']:.4f}")

        # WandB logging
        if self.config.use_wandb:
            wandb.log({
                "epoch": epoch,
                "train_loss": train_metrics["loss"],
                "train_iou": train_metrics["iou"],
                "val_loss": val_metrics["loss"],
                "val_iou": val_metrics["iou"],
                "learning_rate": self.scheduler.get_last_lr()[0]
            })

    def _save_checkpoint(self, filename: str) -> None:
        """Save model checkpoint"""
        state = {
            "epoch": self.scheduler.last_epoch,
            "model_state_dict": self.model.state_dict(),
            "optimizer_state_dict": self.optimizer.state_dict(),
            "scheduler_state_dict": self.scheduler.state_dict(),
            "config": self.config
        }
        torch.save(state, filename)

    def load_checkpoint(self, filename: str) -> None:
        """Load model checkpoint"""
        if not os.path.exists(filename):
            raise FileNotFoundError(f"Checkpoint file {filename} not found")

        checkpoint = torch.load(filename, map_location=self.device)

        self.model.load_state_dict(checkpoint["model_state_dict"])
        self.optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
        self.scheduler.load_state_dict(checkpoint["scheduler_state_dict"])

        # Move model to correct device after loading
        self.model = self.model.to(self.device)

    def predict(self, inputs: torch.Tensor) -> torch.Tensor:
        """Make predictions using the trained model"""
        self.model.eval()
        with torch.inference_mode():
            outputs = self.model(inputs.to(self.device))
            preds = (torch.sigmoid(outputs) > 0.5).float()
        return preds

# %%
# training/metrics.py
import torch
from typing import Dict


class MetricsCalculator:
    """Handles calculation and aggregation of training metrics"""

    def __init__(self):
        self.reset()

    def reset(self):
        """Reset accumulated metrics"""
        self.metrics = {
            "loss": 0.0,
            "iou": 0.0,
            "count": 0
        }

    def update(self, loss: float, iou: float):
        """Update metrics with batch results"""
        self.metrics["loss"] += loss
        self.metrics["iou"] += iou
        self.metrics["count"] += 1

    def compute(self) -> Dict[str, float]:
        """Compute average metrics"""
        count = max(self.metrics["count"], 1)  # Avoid division by zero
        return {
            "loss": self.metrics["loss"] / count,
            "iou": self.metrics["iou"] / count
        }

    @staticmethod
    def calculate_iou(logits: torch.Tensor, target: torch.Tensor, threshold: float) -> float:
        """Calculate IoU score for binary segmentation"""
        preds = (torch.sigmoid(logits) > threshold)
        intersection = (preds & target.bool()).float().sum((1, 2, 3))
        union = (preds | target.bool()).float().sum((1, 2, 3))
        iou = (intersection + 1e-6) / (union + 1e-6)
        return iou.mean().item()

# %% [markdown]
# #### trainer

# %% [markdown]
# #### main

# %%
# main.py
def main():
    # Initialize configuration
    config = TrainingConfig()

    # Create datasets
    train_dataset = BirdsDataset("data/train", config, is_training=True)
    val_dataset = BirdsDataset("data/val", config, is_training=False)

    # Create dataloaders
    train_loader = DataLoader(
        train_dataset, batch_size=config.batch_size, shuffle=True
    )
    val_loader = DataLoader(
        val_dataset, batch_size=config.batch_size, shuffle=False
    )

    # Initialize model
    model = UNet(config).to(config.device)
    trainer = Trainer(model, config)

    trained_model = trainer.train(train_loader, val_loader)
    print("Training completed.")
    return trained_model


if __name__ == "__main__":
    model = main()

# %% [markdown]
# You can also experiment with models and write a small report about results. If the report will be meaningful, you will receive an extra point.

# %% [markdown]
# ### Testing (8 points)
# Your model will be tested on the new data, similar to validation, so use techniques to prevent overfitting the model.
#
# * IoU > 0.85 — 8 points
# * IoU > 0.80 — 7 points
# * IoU > 0.75 — 6 points
# * IoU > 0.70 — 5 points
# * IoU > 0.60 — 4 points
# * IoU > 0.50 — 3 points
# * IoU > 0.40 — 2 points
# * IoU > 0.30 — 1 points

# %%
def predict(model, img_path):
    transform = A.Compose([
        A.Resize(256, 256),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2()
    ])

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transformed = transform(image=img)
    input_tensor = transformed['image'].unsqueeze(0)

    model.eval()
    with torch.no_grad():
        output = model(input_tensor)
        pred = torch.sigmoid(output)
        pred = (pred > 0.5).float()

    # Resize prediction back to original size
    pred = F.interpolate(pred, size=(img.shape[0], img.shape[1]), mode='bilinear', align_corners=False)
    pred = pred.squeeze().numpy()

    return pred

def get_model(path):
    model = UNet()
    model.load_state_dict(torch.load(path))
    model.eval()
    return model

# %%
model = get_model('model_14.pth').to('cuda')

# %%
ious, times = [], []
test_dir = 'data/val/'

for class_name in tqdm(sorted(os.listdir(os.path.join(test_dir, 'images')))):
    for img_name in sorted(os.listdir(os.path.join(test_dir, 'images', class_name))):

        t_start = time()
        pred = predict(model, os.path.join(test_dir, 'images', class_name, img_name))
        times.append(time() - t_start)

        gt_name = img_name.replace('jpg', 'png')
        gt = np.asarray(Image.open(os.path.join(test_dir, 'gt', class_name, gt_name)), dtype = np.uint8)
        if len(gt.shape) > 2:
            gt = gt[:, :, 0]

        iou = get_iou(gt==255, pred>0.5)
        ious.append(iou)

np.mean(ious), np.mean(times)

# %% [markdown]
# ### Compression (1 point)

# %% [markdown]
# Try to speed up the model in any way without losing more than 1% in iou score.
# For example [torch2trt](https://github.com/NVIDIA-AI-IOT/torch2trt)

# %%
def get_fast_model():
    # YOUR CODE HERE
    return model

# %%
fast_model = get_fast_model().to('cuda')

# %%
ious, times = [], []
test_dir = 'data/val/'

for class_name in tqdm(sorted(os.listdir(os.path.join(test_dir, 'images')))):
    for img_name in sorted(os.listdir(os.path.join(test_dir, 'images', class_name))):

        t_start = time()
        pred = predict(fast_model, os.path.join(test_dir, 'images', class_name, img_name))
        times.append(time() - t_start)

        gt_name = img_name.replace('jpg', 'png')
        gt = np.asarray(Image.open(os.path.join(test_dir, 'gt', class_name, gt_name)), dtype = np.uint8)
        if len(gt.shape) > 2:
            gt = gt[:, :, 0]

        iou = get_iou(gt==255, pred>0.5)
        ious.append(iou)

np.mean(ious), np.mean(times)

# %% [markdown]
# **Bonus:** For the best iou score on test(without compression) in group you will get 1.5, 1, 0.5 extra points(for 1st, 2nd, 3rd places).
